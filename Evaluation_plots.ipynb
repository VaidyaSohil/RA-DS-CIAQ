# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [0.6819779634508301,0.684666784097849,0.9424371586791669,0.96040282213438,0.9473415969506882]
ax.bar(langs,students)
ax.set_title('Algorithm vs Score [EVALUATION 1: All variables included]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [3.55,3.54,1.51,1.25,1.44]
ax.bar(langs,students)
ax.set_title('Algorithm vs RMSE [EVALUATION: 1]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('RMSE', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [0.260269307013272,0.26357789249671637,0.7450806248550561,0.7906037505282837,0.7449984477738444]
ax.bar(langs,students)
ax.set_title('Algorithm vs Score [EVALUATION 2: PM10, TF_CNT_1,2,3,4, sin/cos removed]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [5.42,5.40,3.18,2.88,3.18]
ax.bar(langs,students)
ax.set_title('Algorithm vs RMSE [EVALUATION 2: PM10, TF_CNT_1,2,3,4, sin/cos removed]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('RMSE', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [0.19180723497174912,0.19330239052444387,0.5487654349630068,0.6518339445826209,0.5994743139504299]
ax.bar(langs,students)
ax.set_title('Algorithm vs Score [EVALUATION 3: Just removed Hour, Month]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [5.66,5.66,4.23,3.72,3.98]
ax.bar(langs,students)
ax.set_title('Algorithm vs RMSE [EVALUATION 3: Just removed Hour, Month]', fontsize=16)
ax.set_xlabel('Algorithms', fontsize=12)
ax.set_ylabel('RMSE', fontsize=12)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [12,8]

algo = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision', 'BBN-1', 'BBN-2','GGN']
rmse = [3.55, 3.54, 1.51, 1.25, 1.43, 0.90, 1.06, 2.33]
mae = [1.95, 1.97, 0.79, 0.68, 0.73, 0.59, 0.75, 1.53]


df = pd.DataFrame({'RMSE': rmse, 'MAE': mae}, index=algo)
ax = df.plot.bar(rot=45, fontsize = 12)

ax.set_title('Methods vs Error Score [Best Case]', fontsize=16)
ax.set_xlabel('Methods', fontsize=14)
ax.set_ylabel('Error Score', fontsize=14)
plt.show()
