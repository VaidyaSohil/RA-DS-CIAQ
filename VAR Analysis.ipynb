# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]

# %%
lag12_2500 = [3.2956, 2.7208, 3.2845, 3.2271, 3.801]
lag25_2500 = [2.8069, 1.7165, 2.7487, 2.6515, 3.2919]

index = ['mape', 'me', 'mae', 'mpe', 'rmse']
df = pd.DataFrame({'lag12_2500': lag12_2500, 'lag25_2500': lag25_2500}, index=index)
ax = df.plot.bar(rot = 60, fontsize = 14)
ax.set_title("Error Scores (Lag Order 25 vs 12 || 2500)", fontsize=25)
ax.set_xlabel("Mean Error Algorithms", fontsize=20)
ax.set_ylabel("Score", fontsize=20)
# Out:
# Text(0, 0.5, 'Score')

# %%
lag25_500 = [13.4285, 6.714, 6.8049, 13.33, 7.0787]
lag25_2000 = [3.2841, 2.0577, 2.867, 3.1747, 3.3183]
lag25_2500 = [2.8069, 1.7165, 2.7487, 2.6515, 3.2919]
lag25_3000 = [2.5375, 1.9776, 2.6583, 2.4436, 3.163]
lag25_3500 = [2.4193, 2.2528, 2.83, 2.3578, 3.2798]

index = ['mape', 'me', 'mae', 'mpe', 'rmse']
df = pd.DataFrame({'lag25_500': lag25_500, 'lag25_2000': lag25_2000, 'lag25_2500': lag25_2500, 'lag25_3000': lag25_3000, 'lag25_3500': lag25_3500}, index=index)
ax = df.plot.bar(rot = 60, fontsize = 14)
ax.set_title("Error Scores (Lag Order 25)", fontsize=25)
ax.set_xlabel("Mean Error Algorithms", fontsize=20)
ax.set_ylabel("Score", fontsize=20)
# Out:
# Text(0, 0.5, 'Score')

# %%
index = ['mape', 'me', 'mae', 'mpe', 'rmse']
df = pd.DataFrame({'lag25_2000': lag25_2000, 'lag25_2500': lag25_2500, 'lag25_3000': lag25_3000, 'lag25_3500': lag25_3500}, index=index)
ax = df.plot.bar(rot = 60, fontsize = 14)
ax.set_title("Error Scores (Lag Order 25)", fontsize=25)
ax.set_xlabel("Mean Error Algorithms", fontsize=20)
ax.set_ylabel("Score", fontsize=20)
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Lasso', 'ElasticNet', 'Decision','Extra','Boosted decision']
students = [3.55,3.54,1.51,1.25,1.44]
ax.bar(langs,students)
ax.set_title('Algorithm vs RMSE [EVALUATION: 1]', fontsize=20)
ax.set_xlabel('Algorithms', fontsize=20)
ax.set_ylabel('RMSE', fontsize=20)
plt.show()

# %%
lag25_2500 = [0.9013, 0.7587, 1.534, 0.4904, 2.332]
index = ['mape', 'me', 'mae', 'mpe', 'rmse']
df = pd.DataFrame({'lag25_2500': lag25_2500}, index=index)
ax = df.plot.bar(rot = 60, fontsize = 14)
ax.set_title("Error Scores (Lag Order 25)", fontsize=25)
ax.set_xlabel("Mean Error Algorithms", fontsize=20)
ax.set_ylabel("Score", fontsize=20)
# Out:
# Text(0, 0.5, 'Score')

# %%
# Turns out VAR is the best linear model so far (Lasso, Elastic, Linear Regression)
# 35% Split Ratio ====> 2500 test data seem to work best
# RMSE score comparative(slightly lower) to ensemble methods (when fed same features to the model)
